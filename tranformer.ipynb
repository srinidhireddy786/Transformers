# %% [markdown]
# Multihead attention

# %% [markdown]
# Attention mechanism improves context understanding but suffers from high computation high memory usage and poor scalability for long sequences.

# %% [markdown]
# Input and output matching based on  softmax scores

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Self Attention

# %% [markdown]
# We are going to capture information using query ,key and the value(to find a book with name and author  in library)

# %% [markdown]
# Query means what you are looking for and the key is what info to search for and the value is query +key

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Process involved in the self attention based on the paper published by google "Attention is all you need"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Multihead Attention

# %% [markdown]
# Multi head attention means running self attention multiple times in parallel using different heads
#
#
#  z=context aware representation of word
#
#  meaning:after attention the word understands surrounding words

# %% [markdown]
# ![image.png](attachment:image.png)
